# %%
# This is to do the following:
# Take a single GT .dat video, transcode it to ADDER
# Transcode it back to DVS .dat
# Run HMNET inference on it
# Shrink the GT .dat video to match the ADDER version filesize
# Run HMNET inference on that shrunk version

# !cd /home/andrew/Code/HMNet_pth && pip install -r requirements.txt && conda install pytorch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 cudatoolkit=11.3 -c pytorch -y && pip install torch-scatter -f https://data.pyg.org/whl/torch-1.12.1+cu113.html && pip install timm
# !conda install -c conda-forge pycocotools -y

# %%
import sys  
sys.path.insert(1, '/media/andrew/One Touch/HMNET2_crf0')

# %%
# Clear the HMNET data
# !rm /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection/data/gen1/source/detection_dataset_duration_60s_ratio_1.0/test/*.dat
# !rm /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection/data/gen1/test_evt/*.npy
# !rm /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection/workspace/hmnet_B3_yolox_tbptt/result/pred_test/*.npy
# Out:
# rm: cannot remove '/media/andrew/One Touch/HMNET2_autotest/experiments/detection/data/gen1/test_evt/*.npy': No such file or directory
# rm: cannot remove '/media/andrew/One Touch/HMNET2_autotest/experiments/detection/workspace/hmnet_B3_yolox_tbptt/result/pred_test/*.npy': No such file or directory

# %%
input_dat = '/media/andrew/One Touch/HMNet/data/gen1_subset/source/detection_dataset_duration_60s_ratio_1.0/test/17-04-13_15-05-43_1403500000_1463500000_td.dat'
filename = input_dat.split('/')[-1]
adder_out = '/home/andrew/Downloads/hmnet_testing/' + filename.split('.')[0]+'.adder'
dat_out = '/media/andrew/One Touch/HMNET2_autotest/experiments/detection/data/gen1/source/detection_dataset_duration_60s_ratio_1.0/test/' + filename.split('.')[0]+'.dat'
# !cargo run --release --bin prophesee_to_adder -- --ref-time 20 --delta-t-max 40 --input "$input_dat" --output "$adder_out" --crf 9
# !cd /home/andrew/Code/adder-codec-rs/adder-to-dvs && cargo run --release -- --input "$adder_out" --output-events "$dat_out" --theta 0.02
# Out:
# ...
#  --> adder-codec-core/src/codec/compressed/stream.rs:3:15
#   |
# 3 | use std::io::{BufWriter, Cursor, Read, Seek, SeekFrom, Write};
#   |               ^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# ...
#  --> adder-codec-core/src/codec/decoder.rs:1:5
#   |
# 1 | use crate::codec::Magic;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# ...
#   --> adder-codec-core/src/codec/decoder.rs:11:5
#    |
# 11 | use crate::codec::encoder::Encoder;
#    |     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ...
#  --> adder-codec-core/src/codec/compressed/source_model/event_structure/mod.rs:8:11
#   |
# 8 | pub const BLOCK_SIZE_AREA: usize = BLOCK_SIZE * BLOCK_SIZE;
#   |           ^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(dead_code)]` on by default
#
# ...
#   --> adder-codec-core/src/codec/compressed/source_model/event_structure/event_adu.rs:42:5
#    |
# 41 | pub enum AduState {
#    |          -------- variant in this enum
# 42 |     Compressed,
#    |     ^^^^^^^^^^
#    |
# ...

# %%
# Run HMNET on the GT .dat

# !export PYTHONPATH=$PYTHONPATH:"/media/andrew/One Touch/HMNET2_crf0"

# !cd /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection/data/gen1 && echo $(pwd) && bash ./scripts/prepair.sh
# !cd /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection && python ./scripts/test.py ./config/hmnet_B3_yolox_tbptt.py ./data/gen1/list/test/ ./data/gen1/ --pretrained ./pretrained/gen1_hmnet_B3_tbptt.pth --speed_test
# !cd /media/andrew/One\ Touch/HMNET2_autotest/experiments/detection && sh ./scripts/run_eval.sh ./config/hmnet_B3_yolox_tbptt.py
# Out:
# /media/andrew/One Touch/HMNET2_autotest/experiments/detection/data/gen1
# ...
#  Start preprocessing
# ...
# Traceback (most recent call last):
#   File "./scripts/modify_lbl_field_name.py", line 43, in <module>
#     from hmnet.utils.common import get_list, mkdir
#   File "/home/andrew/Code/HMNet_pth/hmnet/utils/common.py", line 43, in <module>
#     import h5py
# ModuleNotFoundError: No module named 'h5py'
# Traceback (most recent call last):
#   File "./scripts/preproc_events.py", line 41, in <module>
#     from hmnet.utils.common import get_list, get_chunk, mkdir
#   File "/home/andrew/Code/HMNet_pth/hmnet/utils/common.py", line 43, in <module>
#     import h5py
# ModuleNotFoundError: No module named 'h5py'
# Done preproc
# Traceback (most recent call last):
#   File "./scripts/validate_bbox.py", line 41, in <module>
#     from hmnet.utils.common import get_list, mkdir
#   File "/home/andrew/Code/HMNet_pth/hmnet/utils/common.py", line 43, in <module>
#     import h5py
# ...

# %%
# !python --version

# %%
# !conda info --envs
